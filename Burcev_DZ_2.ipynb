# %%
# Загрузка библиотек
import requests,math
from tqdm.auto import tqdm

# %%
offset_ = 1 # размер шага
limit_ = 100 # количество объектов в одном ответе api
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)
objects_data = res.json()
objects_data.get('data').get('list')[0]
# Out:
# {'hobjId': 37219,
#  'objId': 13391,
#  'developer': {'devId': 306,
#   'shortName': '2МЕН ГРУПП',
#   'fullName': '2МЕН ГРУПП',
#   'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#   'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#   'companyGroup': 5776,
#   'devInn': '7701651356'},
#  'rpdRegionCd': 72,
#  'objAddr': 'г Тюмень, ул Профсоюзная, д. 56',
#  'objFloorMin': 3,
#  'objFloorMax': 12,
#  'objElemLivingCnt': 44,
#  'objReady100PercDt': '2023-12-31',
#  'objSquareLiving': 4343.9,
#  'objCompensFundFlg': 1,
#  'objProblemFlg': 0,
#  'latitude': 57.1541,
#  'longitude': 65.5595,
#  'problemFlag': 'NONE',
#  'siteStatus': 'Строящиеся',
#  'objGuarantyEscrowFlg': 0,
#  'residentialBuildings': 1,
#  'rpdNum': '72-000096',
#  'pdId': 28101,
#  'buildType': 'Жилое',
#  'objStatus': 0,
#  'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3ABFF857E1B4D64D0497FB96C782D40FEE',
#  'objPriceAVG': 62638,
#  'objPublDt': '2019-05-31'}

# %%
import pandas as pd

# %%
df = pd.json_normalize(objects_data.get('data').get('list'))

# %%
df.head()
# Out:
#    hobjId  objId  rpdRegionCd                             objAddr  \
# 0   37219  13391           72     г Тюмень, ул Профсоюзная, д. 56
# 1   37165  13398           72     г Тюмень, ул Профсоюзная, д. 56
# 2   39024  13383           72     г Тюмень, ул Профсоюзная, д. 56
# 3   37201  13397           72     г Тюмень, ул Профсоюзная, д. 56
# 4    6541  10891           35  г Вологда, ул Медуницинская, д. 11
#
#    objFloorMin  objFloorMax  objElemLivingCnt objReady100PercDt  \
# 0            3           12                44        2023-12-31
# 1            7           10                43        2024-12-31
# 2            4           20                68        2023-12-31
# 3            6           12                65        2024-12-31
# 4           17           17               225        2023-12-31
#
#    objSquareLiving  objCompensFundFlg  ...  developer.orgForm.fullForm  \
# 0          4343.90                  1  ...        Акционерное общество
# 1          4812.98                  0  ...        Акционерное общество
# 2          6423.85                  1  ...        Акционерное общество
# 3          6251.10                  0  ...        Акционерное общество
# 4         12847.23                  1  ...        Акционерное общество
#
#    developer.orgForm.shortForm  developer.companyGroup developer.devInn  \
# 0                           АО                  5776.0       7701651356
# 1                           АО                  5776.0       7701651356
# 2                           АО                  5776.0       7701651356
# 3                           АО                  5776.0       7701651356
# 4                           АО                  7368.0       3525000888
#
#                objCommercNm  complexShortName  \
# 0                       NaN               NaN
# 1                       NaN               NaN
# 2                       NaN               NaN
# 3                       NaN               NaN
# 4  Жилой комплекс "Рафинад"               NaN
#
#    developer.bankruptStage.bankruptStageCd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   developer.bankruptStage.bankruptStageDesc  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    developer.bankruptStage.bankruptLawUrl developer.orgBankruptMsgDttm
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
# [5 rows x 39 columns]

# %%
df.shape
# Out:
# (100, 39)

# %%
# Сохраняем в csv файл
df.to_csv('objects.csv', index=False)
# Сохраняем в эксель-файл
df.to_excel('objects.xlsx', index=False)
# Сохраняем в файл в формате pickle
df.to_pickle('objects.pkl')
